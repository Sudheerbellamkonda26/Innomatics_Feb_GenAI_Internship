# %% [markdown]
# 1. User Login Check
# Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"

# %%
CorrectUsername = "admin"
CorrectPassword = "1234"
username = input("Enter username: ")
password = input("Enter password: ")

if username == CorrectUsername and password == CorrectPassword:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %% [markdown]
# 2. Pass / Fail Analyzer
# Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]

# %%
# List of student marks
marks = [45, 78, 90, 33, 60]

passcount = 0
failcount = 0

# Checking each mark
for mark in marks:
    if mark >= 50:
        passcount = passcount + 1
    else:
        failcount = failcount + 1

print("Passed:", passcount)
print("Failed:", failcount)
# Out:
# Passed: 3
# Failed: 2

# %% [markdown]
# 3. Simple Data Cleaner
# Problem Statement:
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]

# %%
names = [" Alice ", "bob", " CHARLIE "]

newnames = []

for name in names:
    name = name.strip()
    name = name.lower()
    newnames.append(name)

print("names after cleaner:", newnames)
# Out:
# names after cleaner: ['alice', 'bob', 'charlie']

# %% [markdown]
# 4. Message Length Analyzer
# Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]

# %%
messages = ["Hi", "Welcome to the platform", "OK"]

for msg in messages:
    length = len(msg)
    print("Message:", msg)
    print("Length:", length)

    if length > 10:
        print("This message is longer than 10 characters")

    print()
# Out:
# Message: Hi
# Length: 2
#
# Message: Welcome to the platform
# Length: 23
# This message is longer than 10 characters
#
# Message: OK
# Length: 2

# %% [markdown]
# 5. Error Message Detector
# Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

errorcount = 0

for log in logs:
    if log == "ERROR":
        errorcount = errorcount + 1

print("Total number of ERROR messages:", errorcount)
# Out:
# Total number of ERROR messages: 2
